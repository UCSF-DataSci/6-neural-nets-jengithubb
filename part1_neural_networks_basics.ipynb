# %% [markdown]
# # Part 1: Neural Networks Basics
#
# ## Introduction
#
# In this part, you'll implement a simple neural network for EMNIST character recognition. This will help you understand the fundamentals of neural networks, including dense layers, activation functions, and dropout.
#
# ## Learning Objectives
#
# - Load and preprocess EMNIST dataset
# - Implement a simple neural network with dense layers
# - Train and evaluate the model
# - Save model and metrics in the correct format
#
# ## Setup and Installation

# %%
# Install required packages
# %pip install -r requirements.txt

# Import necessary libraries
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os


import tensorflow_datasets as tfds
emnist_dataset, emnist_info = tfds.load(
  'emnist/byclass',
  split=['train', 'test'],
  as_supervised=True, # Returns tuple (img, label) instead of dict
  with_info=True, # Includes dataset metadata
)


# Set random seeds for reproducibility
tf.random.set_seed(42)
np.random.seed(42)

# Configure matplotlib for better visualization
# plt.style.use('seaborn')
plt.style.use('seaborn-v0_8') 
plt.rcParams['figure.figsize'] = (12, 8)
plt.rcParams['font.size'] = 12

# Create directories
os.makedirs('models', exist_ok=True)
os.makedirs('results/part_1', exist_ok=True)
os.makedirs('logs', exist_ok=True)
# Out:
# Requirement already satisfied: pytest in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 4)) (8.3.5)
# Requirement already satisfied: nbformat in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 7)) (5.10.4)
# Requirement already satisfied: ipykernel in /Users/jenniferzhu/Library/Python/3.12/lib/python/site-packages (from -r requirements.txt (line 8)) (6.29.4)
# Requirement already satisfied: nbclient in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 9)) (0.10.0)
# Requirement already satisfied: pandas<3.0,>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 12)) (2.2.2)
# Requirement already satisfied: numpy<3.0,>=1.20 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 13)) (1.26.4)
# Requirement already satisfied: scikit-learn<2.0,>=1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 14)) (1.5.0)
# Requirement already satisfied: xgboost<3.0,>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 15)) (2.1.4)
# Requirement already satisfied: imbalanced-learn<1.0,>=0.9 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 16)) (0.13.0)
# Requirement already satisfied: matplotlib<4.0,>=3.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 17)) (3.9.0)
# Requirement already satisfied: seaborn<1.0,>=0.11 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from -r requirements.txt (line 18)) (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas<3.0,>=1.5->-r requirements.txt (line 12)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas<3.0,>=1.5->-r requirements.txt (line 12)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas<3.0,>=1.5->-r requirements.txt (line 12)) (2024.1)
# Requirement already satisfied: scipy>=1.6.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn<2.0,>=1.0->-r requirements.txt (line 14)) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn<2.0,>=1.0->-r requirements.txt (line 14)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn<2.0,>=1.0->-r requirements.txt (line 14)) (3.5.0)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from imbalanced-learn<1.0,>=0.9->-r requirements.txt (line 16)) (0.1.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib<4.0,>=3.5->-r requirements.txt (line 17)) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib<4.0,>=3.5->-r requirements.txt (line 17)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib<4.0,>=3.5->-r requirements.txt (line 17)) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib<4.0,>=3.5->-r requirements.txt (line 17)) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib<4.0,>=3.5->-r requirements.txt (line 17)) (24.1)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib<4.0,>=3.5->-r requirements.txt (line 17)) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib<4.0,>=3.5->-r requirements.txt (line 17)) (3.1.2)
# Requirement already satisfied: iniconfig in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pytest->-r requirements.txt (line 4)) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pytest->-r requirements.txt (line 4)) (1.5.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nbformat->-r requirements.txt (line 7)) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from nbformat->-r requirements.txt (line 7)) (4.23.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /Users/jenniferzhu/Library/Python/3.12/lib/python/site-packages (from nbformat->-r requirements.txt (line 7)) (5.7.2)
# Requirement already satisfied: traitlets>=5.1 in /Users/jenniferzhu/Library/Python/3.12/lib/python/site-packages (from nbformat->-r requirements.txt (line 7)) (5.14.3)
# Requirement already satisfied: appnope in /Users/jenniferzhu/Library/Python/3.12/lib/python/site-packages (from ipykernel->-r requirements.txt (line 8)) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/jenniferzhu/Library/Python/3.12/lib/python/site-packages (from ipykernel->-r requirements.txt (line 8)) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/jenniferzhu/Library/Python/3.12/lib/python/site-packages (from ipykernel->-r requirements.txt (line 8)) (1.8.1)
# Requirement already satisfied: ipython>=7.23.1 in /Users/jenniferzhu/Library/Python/3.12/lib/python/site-packages (from ipykernel->-r requirements.txt (line 8)) (8.25.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/jenniferzhu/Library/Python/3.12/lib/python/site-packages (from ipykernel->-r requirements.txt (line 8)) (8.6.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/jenniferzhu/Library/Python/3.12/lib/python/site-packages (from ipykernel->-r requirements.txt (line 8)) (0.1.7)
# Requirement already satisfied: nest-asyncio in /Users/jenniferzhu/Library/Python/3.12/lib/python/site-packages (from ipykernel->-r requirements.txt (line 8)) (1.6.0)
# Requirement already satisfied: psutil in /Users/jenniferzhu/Library/Python/3.12/lib/python/site-packages (from ipykernel->-r requirements.txt (line 8)) (5.9.8)
# Requirement already satisfied: pyzmq>=24 in /Users/jenniferzhu/Library/Python/3.12/lib/python/site-packages (from ipykernel->-r requirements.txt (line 8)) (26.0.3)
# Requirement already satisfied: tornado>=6.1 in /Users/jenniferzhu/Library/Python/3.12/lib/python/site-packages (from ipykernel->-r requirements.txt (line 8)) (6.4.1)
# Requirement already satisfied: decorator in /Users/jenniferzhu/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/jenniferzhu/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/jenniferzhu/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in /Users/jenniferzhu/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (2.18.0)
# Requirement already satisfied: stack-data in /Users/jenniferzhu/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (0.6.3)
# Requirement already satisfied: pexpect>4.3 in /Users/jenniferzhu/Library/Python/3.12/lib/python/site-packages (from ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (4.9.0)
# Requirement already satisfied: wcwidth in /Users/jenniferzhu/Library/Python/3.12/lib/python/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/jenniferzhu/Library/Python/3.12/lib/python/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->-r requirements.txt (line 7)) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->-r requirements.txt (line 7)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->-r requirements.txt (line 7)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jsonschema>=2.6->nbformat->-r requirements.txt (line 7)) (0.20.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/jenniferzhu/Library/Python/3.12/lib/python/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->-r requirements.txt (line 7)) (4.2.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/jenniferzhu/Library/Python/3.12/lib/python/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3.0,>=1.5->-r requirements.txt (line 12)) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/jenniferzhu/Library/Python/3.12/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/jenniferzhu/Library/Python/3.12/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/jenniferzhu/Library/Python/3.12/lib/python/site-packages (from stack-data->ipython>=7.23.1->ipykernel->-r requirements.txt (line 8)) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 1. Data Loading and Preprocessing

# %%
# Load EMNIST dataset
#(x_train, y_train), (x_test, y_test) = tf.keras.datasets.emnist.load_data('letters')
(ds_train, ds_test), ds_info = tfds.load(
    'emnist/letters',
    split=['train', 'test'],
    as_supervised=True,
    with_info=True
)

# Convert to NumPy arrays
x_train = []
y_train = []
for img, label in tfds.as_numpy(ds_train):
    x_train.append(img)
    y_train.append(label)
x_train = np.array(x_train)
y_train = np.array(y_train)

x_test = []
y_test = []
for img, label in tfds.as_numpy(ds_test):
    x_test.append(img)
    y_test.append(label)
x_test = np.array(x_test)
y_test = np.array(y_test)

# Print dataset information
print(f"Training data shape: {x_train.shape}")
print(f"Test data shape: {x_test.shape}")
print(f"Number of classes: {len(np.unique(y_train))}")

# Plot sample images
plt.figure(figsize=(15, 5))
for i in range(5):
    plt.subplot(1, 5, i + 1)
    plt.imshow(np.squeeze(x_train[i]).T, cmap='gray')
    plt.title(f'Label: {chr(y_train[i] + 64)}')
    plt.axis('off')
plt.show()
# Out:
# WARNING:absl:Variant folder /Users/jenniferzhu/tensorflow_datasets/emnist/letters/3.1.0 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /Users/jenniferzhu/tensorflow_datasets/emnist/letters/3.1.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /Users/jenniferzhu/tensorflow_datasets/emnist/letters/incomplete.0I51RA_3.1.0/emnist-train.tfrecord*…
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /Users/jenniferzhu/tensorflow_datasets/emnist/letters/incomplete.0I51RA_3.1.0/emnist-test.tfrecord*.…
# Dataset emnist downloaded and prepared to /Users/jenniferzhu/tensorflow_datasets/emnist/letters/3.1.0. Subsequent calls will reuse this data.
# Training data shape: (88800, 28, 28, 1)
# Test data shape: (14800, 28, 28, 1)
# Number of classes: 26

# %%
# Preprocess data
# Normalize pixel values
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# Reshape for dense layers
x_train = x_train.reshape(-1, 28 * 28)
x_test = x_test.reshape(-1, 28 * 28)

# Convert labels to one-hot encoding
y_train = tf.keras.utils.to_categorical(y_train - 1, num_classes=26)
y_test = tf.keras.utils.to_categorical(y_test - 1, num_classes=26)

# Split training data into train and validation
from sklearn.model_selection import train_test_split
x_train, x_val, y_train, y_val = train_test_split(
    x_train, y_train, test_size=0.2, random_state=42
)

print(f"Preprocessed training data shape: {x_train.shape}")
print(f"Preprocessed validation data shape: {x_val.shape}")
print(f"Preprocessed test data shape: {x_test.shape}")
# Out:
# Preprocessed training data shape: (71040, 784)
# Preprocessed validation data shape: (17760, 784)
# Preprocessed test data shape: (14800, 784)

# %% [markdown]
# ## 2. Model Implementation

# %%
# Create simple neural network
def create_simple_nn(input_shape, num_classes):
    """
    Create a simple neural network for EMNIST classification.
    
    Requirements:
    - Must use at least 2 dense layers
    - Must include dropout layers
    - Must use categorical crossentropy loss
    
    Goals:
    - Achieve > 80% accuracy on test set
    - Minimize overfitting using dropout
    - Train efficiently with appropriate batch size
    
    Args:
        input_shape: Shape of input data (should be (784,) for flattened 28x28 images)
        num_classes: Number of output classes (26 for letters)
    
    Returns:
        Compiled Keras model
    """
    model = tf.keras.Sequential([
        tf.keras.layers.InputLayer(input_shape=input_shape),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(256, activation='relu'),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(num_classes, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    return model

# Create and compile model
model = create_simple_nn(input_shape=(784,), num_classes=26)
model.summary()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 512)            │       401,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 26)             │         6,682 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 539,930 (2.06 MB)
#  Trainable params: 539,930 (2.06 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## 3. Training and Evaluation

# %%
# Define callbacks
callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=5,
        restore_best_weights=True
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.2,
        patience=3
    ),
    tf.keras.callbacks.ModelCheckpoint(
        'models/emnist_classifier.keras',
        save_best_only=True
    )
]

# Train model
history = model.fit(
    x_train, y_train,
    validation_data=(x_val, y_val),
    epochs=20,
    batch_size=32,
    callbacks=callbacks
)

# Plot training curves
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

# Plot accuracy
ax1.plot(history.history['accuracy'], label='Training')
ax1.plot(history.history['val_accuracy'], label='Validation')
ax1.set_title('Model Accuracy')
ax1.set_xlabel('Epoch')
ax1.set_ylabel('Accuracy')
ax1.legend()

# Plot loss
ax2.plot(history.history['loss'], label='Training')
ax2.plot(history.history['val_loss'], label='Validation')
ax2.set_title('Model Loss')
ax2.set_xlabel('Epoch')
ax2.set_ylabel('Loss')
ax2.legend()

plt.tight_layout()
plt.show()
# Out:
# Epoch 1/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.6310 - loss: 1.2385 - val_accuracy: 0.8580 - val_loss: 0.4460 - learning_rate: 0.0010
# Epoch 2/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.8268 - loss: 0.5421 - val_accuracy: 0.8827 - val_loss: 0.3710 - learning_rate: 0.0010
# Epoch 3/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8565 - loss: 0.4493 - val_accuracy: 0.8881 - val_loss: 0.3434 - learning_rate: 0.0010
# Epoch 4/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.8671 - loss: 0.4085 - val_accuracy: 0.8974 - val_loss: 0.3248 - learning_rate: 0.0010
# Epoch 5/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.8766 - loss: 0.3753 - val_accuracy: 0.8970 - val_loss: 0.3261 - learning_rate: 0.0010
# Epoch 6/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.8830 - loss: 0.3516 - val_accuracy: 0.9012 - val_loss: 0.3108 - learning_rate: 0.0010
# Epoch 7/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8858 - loss: 0.3369 - val_accuracy: 0.9035 - val_loss: 0.3036 - learning_rate: 0.0010
# Epoch 8/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.8895 - loss: 0.3263 - val_accuracy: 0.9015 - val_loss: 0.3034 - learning_rate: 0.0010
# Epoch 9/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8940 - loss: 0.3138 - val_accuracy: 0.9027 - val_loss: 0.3209 - learning_rate: 0.0010
# Epoch 10/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8961 - loss: 0.3048 - val_accuracy: 0.9045 - val_loss: 0.3042 - learning_rate: 0.0010
# Epoch 11/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.8964 - loss: 0.3019 - val_accuracy: 0.9066 - val_loss: 0.3064 - learning_rate: 0.0010
# Epoch 12/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9143 - loss: 0.2412 - val_accuracy: 0.9162 - val_loss: 0.2798 - learning_rate: 2.0000e-04
# Epoch 13/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9241 - loss: 0.2102 - val_accuracy: 0.9180 - val_loss: 0.2763 - learning_rate: 2.0000e-04
# Epoch 14/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9283 - loss: 0.1951 - val_accuracy: 0.9177 - val_loss: 0.2749 - learning_rate: 2.0000e-04
# Epoch 15/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9327 - loss: 0.1821 - val_accuracy: 0.9182 - val_loss: 0.2758 - learning_rate: 2.0000e-04
# Epoch 16/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - accuracy: 0.9356 - loss: 0.1742 - val_accuracy: 0.9188 - val_loss: 0.2751 - learning_rate: 2.0000e-04
# Epoch 17/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9354 - loss: 0.1765 - val_accuracy: 0.9181 - val_loss: 0.2785 - learning_rate: 2.0000e-04
# Epoch 18/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9380 - loss: 0.1675 - val_accuracy: 0.9204 - val_loss: 0.2739 - learning_rate: 4.0000e-05
# Epoch 19/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9407 - loss: 0.1592 - val_accuracy: 0.9207 - val_loss: 0.2752 - learning_rate: 4.0000e-05
# Epoch 20/20
# 2220/2220 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - accuracy: 0.9404 - loss: 0.1535 - val_accuracy: 0.9213 - val_loss: 0.2746 - learning_rate: 4.0000e-05

# %%
# Evaluate model
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_accuracy:.4f}")

# Get predictions
predictions = model.predict(x_test)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(y_test, axis=1)

# Calculate confusion matrix
cm = tf.math.confusion_matrix(true_labels, predicted_labels)

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

from sklearn.metrics import precision_score, recall_score, f1_score
precision = precision_score(true_labels, predicted_labels, average='weighted')
recall = recall_score(true_labels, predicted_labels, average='weighted')
f1 = f1_score(true_labels, predicted_labels, average='weighted')

# Save metrics
metrics = {
    'model': 'emnist_classifier',
    'accuracy': float(test_accuracy),
    'precision': float(precision),
    'recall': float(recall),
    'f1_score': float(f1),
    'confusion_matrix': cm.numpy().tolist()
}

# Save to file
with open('results/part_1/emnist_classifier_metrics.txt', 'w') as f:
    f.write(f"model: {metrics['model']}\n")
    f.write(f"accuracy: {metrics['accuracy']}\n")
    f.write(f"precision: {metrics['precision']}\n")
    f.write(f"recall: {metrics['recall']}\n")
    f.write(f"f1_score: {metrics['f1_score']}\n")
    f.write(f"confusion_matrix: {metrics['confusion_matrix']}\n")
    f.write("----\n")
# Out:
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9082 - loss: 0.3201
# Test accuracy: 0.9070
# 463/463 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1517: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
